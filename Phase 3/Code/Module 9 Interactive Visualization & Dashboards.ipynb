# %% [markdown]
# # Module 9: Interactive Visualization & Dashboards
# ## Objective: Building user-centric analytical tools with Plotly and Streamlit.
#
# Static charts are for evidence; interactive dashboards are for discovery.
# In this module, we will learn how to build visualizations that users can
# "touch" and dashboards that run as live web applications.

# %% [markdown]
# ### 1. The Power of Hover and Zoom
# Plotly Express allows us to create complex interactive charts with minimal code.
# Unlike Matplotlib, these charts are rendered in HTML, allowing for fluid
# interaction in any web browser.

# %%
import plotly.express as px
import pandas as pd

# Load sample regional data
df = px.data.gapminder().query("year == 2007")

# Create an interactive scatter plot
fig = px.scatter(df, x="gdpPercap", y="lifeExp",
                 size="pop", color="continent",
                 hover_name="country", log_x=True, size_max=60,
                 title="Global Wealth vs. Health (Interactive)")

# In a notebook, this will render an interactive window
fig.show()

# %% [markdown]
# ### 2. Streamlit: Python to Web App
# Streamlit does not run like a normal script; it re-runs every time a user
# interacts with a widget.
#
# **Note**: To run Streamlit, you must save your code in a `.py` file and
# run `streamlit run your_file.py` in your terminal. Below is the structure
# of a professional dashboard script.

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px

st.set_page_config(page_title="Regional Analytics", layout="wide")

st.title("🚀 Regional Analytics Dashboard")

# Fix: Use np.random.rand (positive 0-1) or np.random.uniform (specific range)
# Standard normal (randn) produces negative numbers which 'size' cannot accept.
df = pd.DataFrame({
    'Crop Yield': np.random.uniform(50, 100, 20),
    'Rainfall': np.random.uniform(10, 50, 20),
    'Temperature': np.random.uniform(15, 45, 20)
})

st.write("### Data Preview", df)

# Create the interactive chart
# All values in "Temperature" are now positive, so 'size' will work perfectly.
fig = px.scatter(
    df, 
    x="Rainfall", 
    y="Crop Yield", 
    size="Temperature", 
    color="Crop Yield",
    title="Impact of Rainfall on Crop Yield",
    template="plotly_dark"
)

st.plotly_chart(fig, use_container_width=True)
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py
# Out:
# ^C

# %% [markdown]
# ### 3. Widgets: Putting the User in Control
# Widgets allow us to capture user input and use it to filter our data
# dynamically. This is how we move from "Coding" to "Product Development."

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px

# 1. Page Configuration
st.set_page_config(page_title="Regional Analytics", layout="wide")

st.title("🚀 Regional Analytics Dashboard")

# 2. Sidebar for Navigation/Inputs
st.sidebar.header("Configuration")
region = st.sidebar.selectbox(
    'Select the Target Region',
    ('Peshawar', 'Mardan', 'Swat', 'Kohat')
)

# 3. Main Interface Widgets
threshold = st.slider('Select Success Threshold (%)', 0, 100, 50)

# Dynamic Filtering Text
st.write(f"Displaying results for **{region}** with a threshold of **{threshold}%**")

# 4. Analysis Logic Trigger
if st.button('Run Analysis'):
    st.success(f"Analysis complete for {region}!")
    
    # Generate positive random data for the analysis
    df = pd.DataFrame({
        'Crop Yield': np.random.uniform(50, 100, 20),
        'Rainfall': np.random.uniform(10, 50, 20),
        'Temperature': np.random.uniform(15, 45, 20)
    })

    st.write("### Analysis Data Preview", df)

    # 5. Interactive Visualization
    # Using 'Temperature' for size (ensured positive to avoid ValueErrors)
    fig = px.scatter(
        df, 
        x="Rainfall", 
        y="Crop Yield", 
        size="Temperature", 
        color="Crop Yield",
        title=f"Impact of Rainfall on Crop Yield in {region}",
        template="plotly_dark",
        labels={"Crop Yield": "Yield (Tons)", "Rainfall": "Rainfall (mm)"}
    )

    st.plotly_chart(fig, use_container_width=True)
else:
    st.info("Click 'Run Analysis' to generate the regional report and visualization.")
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py
# Out:
# ^C

# %% [markdown]
# ### Student Exercise: The Interactive Regional Planner
# **Goal**: Build a mini-dashboard that allows a user to explore crop yields.
# 1. Create a synthetic dataset for 5 different crops across 4 districts.
# 2. Use **Plotly Express** to create a Bar Chart where the colors change based
#    on the "District."
# 3. Draft a **Streamlit** script that:
#     - Has a **Dropdown** to select the Crop.
#     - Has a **Checkbox** to "Show Raw Data."
#     - Displays a **Plotly Chart** that updates automatically based on the
#       dropdown selection.
# 4. **Final Step**: Save your work as `final_dashboard.py` and launch it in
#    your browser using the terminal.
